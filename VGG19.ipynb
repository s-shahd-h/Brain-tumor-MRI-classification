# %% [markdown]
# <a href="https://colab.research.google.com/github/s-shahd-h/Brain-tumor-MRI-classification/blob/main/VGG19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras,os
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.layers import Input, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.vgg19 import preprocess_input, VGG19  # Import VGG19 from the correct location

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("tombackert/brain-tumor-mri-data")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.5)
# Path to dataset files: /root/.cache/kagglehub/datasets/tombackert/brain-tumor-mri-data/versions/1

# %%
print("Contents of the base path:")
print(os.listdir(path))
# Out:
# Contents of the base path:
# ['brain-tumor-mri-dataset']

# %%
dataset_path = os.path.join(path, "brain-tumor-mri-dataset")

# Check the contents of the dataset folder
print("Contents of 'Brain Tumor Dataset':")
classes =os.listdir(dataset_path)
print(classes)
# Out:
# Contents of 'Lung Disease Dataset':
# ['meningioma', 'notumor', 'pituitary', 'glioma']

# %%
import os
import shutil
from sklearn.model_selection import train_test_split

# Directories for train and test splits
train_dir = "dataset/train"
test_dir = "dataset/test"

# Create train and test directories with subfolders for each class
for directory in [train_dir, test_dir]:
    for class_name in classes:
        os.makedirs(os.path.join(directory, class_name), exist_ok=True)

# Split the data for each class
for class_name in classes:
    class_path = os.path.join(dataset_path, class_name)
    images = os.listdir(class_path)

    # Split images into train and test
    train_images, test_images = train_test_split(images, test_size=0.2, random_state=42)

    # Move images to train directory
    for image in train_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(train_dir, class_name))

    # Move images to test directory
    for image in test_images:
        shutil.copy(os.path.join(class_path, image), os.path.join(test_dir, class_name))

print("Dataset split into train and test successfully!")
# Out:
# Dataset split into train and test successfully!

# %%
import os

def count_images_in_directory(directory_path):
    total_images = 0
    class_counts = {}

    for class_name in os.listdir(directory_path):
        class_path = os.path.join(directory_path, class_name)
        if os.path.isdir(class_path):
            num_images = len(os.listdir(class_path))
            class_counts[class_name] = num_images
            total_images += num_images

    return total_images, class_counts

# Paths to train and test directories
train_dir = "dataset/train"
test_dir = "dataset/test"

# Count images
train_total, train_counts = count_images_in_directory(train_dir)
test_total, test_counts = count_images_in_directory(test_dir)

# Display results
print("Training Set:")
print(f"  Total images: {train_total}")
for label, count in train_counts.items():
    print(f"  {label}: {count} images")

print("\nTest Set:")
print(f"  Total images: {test_total}")
for label, count in test_counts.items():
    print(f"  {label}: {count} images")
# Out:
# Training Set:
#   Total images: 5721
#   meningioma: 1420 images
#   notumor: 1600 images
#   pituitary: 1405 images
#   glioma: 1296 images
#
# Test Set:
#   Total images: 1432
#   meningioma: 355 images
#   notumor: 400 images
#   pituitary: 352 images
#   glioma: 325 images

# %%
# Parameters
img_size = 224
batch_size = 32
epochs = 70
num_classes = 4  # Number of classes in the dataset
target_size = (img_size, img_size)

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator


original_datagen = ImageDataGenerator(rescale=1.0 / 255.0)


original_generator = original_datagen.flow_from_directory(
    "dataset/train",
    target_size=(224, 224),
    batch_size=32,
    class_mode="categorical",
    shuffle=True
)


for images, labels in original_generator:
    plt.figure(figsize=(10, 10))
    for i in range(9):
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[i])
        plt.axis("off")
    break
# Out:
# Found 5721 images belonging to 4 classes.

# %%
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_input,  # VGG19-specific preprocessing
    validation_split=0.2,
    rotation_range=20,      # Randomly rotate images by up to 20 degrees
    width_shift_range=0.2,   # Randomly shift images horizontally by up to 20% of the width
    height_shift_range=0.2,  # Randomly shift images vertically by up to 20% of the height
    shear_range=0.2,        # Randomly apply shearing transformations
    zoom_range=0.2,         # Randomly zoom in or out on images
    horizontal_flip=True,   # Randomly flip images horizontally
    fill_mode='nearest'     # Fill in missing pixels using the nearest neighbor
)



test_datagen = ImageDataGenerator(preprocessing_function=preprocess_input,
 )

# %%
# Training data generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    subset='training',
    class_mode='categorical',  # For multi-class classification
    shuffle=True
)

# validation data generator
val_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=target_size,
    batch_size=batch_size,
    subset='validation',
    class_mode='categorical',  # For multi-class classification
    shuffle=True
)


# Test data generator
test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=target_size,
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 4577 images belonging to 4 classes.
# Found 1144 images belonging to 4 classes.
# Found 1432 images belonging to 4 classes.

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D
def create_model():
    # Load VGG19 model with pretrained weights, excluding the top (fully connected) layers
    VGG_base = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


    for layer in VGG_base.layers[:15]:
        layer.trainable = False

    # Build the model
    model = Sequential([
        VGG_base,  # Add the base model
        GlobalAveragePooling2D(),  # Replace Flatten with GAP for efficiency
        Dense(256, activation='relu', kernel_regularizer=l2(0.02)),  # Regularization
        BatchNormalization(),
        Dropout(0.6),  # Prevent overfitting
        Dense(128, activation='relu',kernel_regularizer=l2(0.01)),
        BatchNormalization(),
        Dropout(0.5),
        Dense(4, activation='softmax')  # For multi-class classification

    ])


    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy',metrics=['accuracy'])
    return model

model = create_model()

# %%
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

class_weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_generator.classes),
    y=train_generator.classes
)

class_weights_dict = dict(enumerate(class_weights))

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(
 monitor='val_loss',
 factor=0.5,
 patience=3,
 min_lr=1e-6,
 verbose=1
)

# Callbacks
early_stopping_monitor = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6, verbose=1)

# %%
# Train the model with additional regularization
History = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    class_weight=class_weights_dict,
    callbacks=[early_stopping_monitor, lr_scheduler]
)
# Out:
# Epoch 1/70
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 134s 733ms/step - accuracy: 0.3927 - loss: 9.9884 - val_accuracy: 0.3497 - val_loss: 9.9002 - learning_rate: 1.0000e-04
# Epoch 2/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 95s 567ms/step - accuracy: 0.6375 - loss: 7.8688 - val_accuracy: 0.7587 - val_loss: 6.6170 - learning_rate: 1.0000e-04
# Epoch 3/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 598ms/step - accuracy: 0.7480 - loss: 6.4437 - val_accuracy: 0.2815 - val_loss: 13.7796 - learning_rate: 1.0000e-04
# Epoch 4/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 601ms/step - accuracy: 0.7487 - loss: 5.5253 - val_accuracy: 0.8698 - val_loss: 4.7128 - learning_rate: 1.0000e-04
# Epoch 5/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 138s 566ms/step - accuracy: 0.8432 - loss: 4.5997 - val_accuracy: 0.4406 - val_loss: 8.8141 - learning_rate: 1.0000e-04
# Epoch 6/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 563ms/step - accuracy: 0.8534 - loss: 4.0567 - val_accuracy: 0.2832 - val_loss: 7.9811 - learning_rate: 1.0000e-04
# Epoch 7/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 144s 574ms/step - accuracy: 0.9021 - loss: 3.5484 - val_accuracy: 0.7561 - val_loss: 3.8353 - learning_rate: 1.0000e-04
# Epoch 8/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 559ms/step - accuracy: 0.9220 - loss: 3.1555 - val_accuracy: 0.9205 - val_loss: 2.9703 - learning_rate: 1.0000e-04
# Epoch 9/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 571ms/step - accuracy: 0.9257 - loss: 2.8910 - val_accuracy: 0.2815 - val_loss: 11.1778 - learning_rate: 1.0000e-04
# Epoch 10/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 87s 584ms/step - accuracy: 0.7657 - loss: 3.1177 - val_accuracy: 0.4694 - val_loss: 5.2092 - learning_rate: 1.0000e-04
# Epoch 11/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step - accuracy: 0.9012 - loss: 2.5484
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 568ms/step - accuracy: 0.9013 - loss: 2.5480 - val_accuracy: 0.6031 - val_loss: 4.1893 - learning_rate: 1.0000e-04
# Epoch 12/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 568ms/step - accuracy: 0.9173 - loss: 2.3643 - val_accuracy: 0.9161 - val_loss: 2.3125 - learning_rate: 5.0000e-05
# Epoch 13/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 604ms/step - accuracy: 0.9455 - loss: 2.2305 - val_accuracy: 0.8706 - val_loss: 2.4225 - learning_rate: 5.0000e-05
# Epoch 14/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 568ms/step - accuracy: 0.9575 - loss: 2.1320 - val_accuracy: 0.8671 - val_loss: 2.3412 - learning_rate: 5.0000e-05
# Epoch 15/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.9541 - loss: 2.0526
# Epoch 15: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 87s 582ms/step - accuracy: 0.9541 - loss: 2.0525 - val_accuracy: 0.7876 - val_loss: 2.5288 - learning_rate: 5.0000e-05
# Epoch 16/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 140s 564ms/step - accuracy: 0.9598 - loss: 1.9761 - val_accuracy: 0.9554 - val_loss: 1.9793 - learning_rate: 2.5000e-05
# Epoch 17/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 573ms/step - accuracy: 0.9723 - loss: 1.9227 - val_accuracy: 0.9703 - val_loss: 1.9034 - learning_rate: 2.5000e-05
# Epoch 18/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 566ms/step - accuracy: 0.9692 - loss: 1.8831 - val_accuracy: 0.9493 - val_loss: 1.9015 - learning_rate: 2.5000e-05
# Epoch 19/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 561ms/step - accuracy: 0.9755 - loss: 1.8345 - val_accuracy: 0.9677 - val_loss: 1.8448 - learning_rate: 2.5000e-05
# Epoch 20/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 567ms/step - accuracy: 0.9800 - loss: 1.7918 - val_accuracy: 0.9528 - val_loss: 1.8344 - learning_rate: 2.5000e-05
# Epoch 21/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 562ms/step - accuracy: 0.9732 - loss: 1.7599 - val_accuracy: 0.9703 - val_loss: 1.7573 - learning_rate: 2.5000e-05
# Epoch 22/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 566ms/step - accuracy: 0.9771 - loss: 1.7157 - val_accuracy: 0.9712 - val_loss: 1.7213 - learning_rate: 2.5000e-05
# Epoch 23/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 568ms/step - accuracy: 0.9856 - loss: 1.6608 - val_accuracy: 0.9615 - val_loss: 1.7049 - learning_rate: 2.5000e-05
# Epoch 24/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 605ms/step - accuracy: 0.9774 - loss: 1.6412 - val_accuracy: 0.9773 - val_loss: 1.6250 - learning_rate: 2.5000e-05
# Epoch 25/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 86s 579ms/step - accuracy: 0.9855 - loss: 1.5789 - val_accuracy: 0.9747 - val_loss: 1.5899 - learning_rate: 2.5000e-05
# Epoch 26/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 573ms/step - accuracy: 0.9804 - loss: 1.5504 - val_accuracy: 0.9747 - val_loss: 1.5550 - learning_rate: 2.5000e-05
# Epoch 27/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 86s 568ms/step - accuracy: 0.9887 - loss: 1.4926 - val_accuracy: 0.9712 - val_loss: 1.5232 - learning_rate: 2.5000e-05
# Epoch 28/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 571ms/step - accuracy: 0.9854 - loss: 1.4590 - val_accuracy: 0.9572 - val_loss: 1.5255 - learning_rate: 2.5000e-05
# Epoch 29/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 570ms/step - accuracy: 0.9843 - loss: 1.4226 - val_accuracy: 0.9528 - val_loss: 1.4993 - learning_rate: 2.5000e-05
# Epoch 30/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 566ms/step - accuracy: 0.9888 - loss: 1.3795 - val_accuracy: 0.9712 - val_loss: 1.4095 - learning_rate: 2.5000e-05
# Epoch 31/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 140s 566ms/step - accuracy: 0.9894 - loss: 1.3278 - val_accuracy: 0.9773 - val_loss: 1.3420 - learning_rate: 2.5000e-05
# Epoch 32/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 567ms/step - accuracy: 0.9908 - loss: 1.2867 - val_accuracy: 0.9694 - val_loss: 1.3470 - learning_rate: 2.5000e-05
# Epoch 33/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 569ms/step - accuracy: 0.9894 - loss: 1.2504 - val_accuracy: 0.9790 - val_loss: 1.2619 - learning_rate: 2.5000e-05
# Epoch 34/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 567ms/step - accuracy: 0.9897 - loss: 1.2063 - val_accuracy: 0.9659 - val_loss: 1.2514 - learning_rate: 2.5000e-05
# Epoch 35/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 563ms/step - accuracy: 0.9906 - loss: 1.1738 - val_accuracy: 0.9799 - val_loss: 1.1821 - learning_rate: 2.5000e-05
# Epoch 36/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 594ms/step - accuracy: 0.9940 - loss: 1.1195 - val_accuracy: 0.9659 - val_loss: 1.1963 - learning_rate: 2.5000e-05
# Epoch 37/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 561ms/step - accuracy: 0.9934 - loss: 1.0810 - val_accuracy: 0.9816 - val_loss: 1.1006 - learning_rate: 2.5000e-05
# Epoch 38/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 570ms/step - accuracy: 0.9920 - loss: 1.0492 - val_accuracy: 0.9703 - val_loss: 1.1006 - learning_rate: 2.5000e-05
# Epoch 39/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 556ms/step - accuracy: 0.9898 - loss: 1.0174 - val_accuracy: 0.9336 - val_loss: 1.1823 - learning_rate: 2.5000e-05
# Epoch 40/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 565ms/step - accuracy: 0.9927 - loss: 0.9737 - val_accuracy: 0.9755 - val_loss: 1.0221 - learning_rate: 2.5000e-05
# Epoch 41/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 568ms/step - accuracy: 0.9944 - loss: 0.9339 - val_accuracy: 0.9834 - val_loss: 0.9462 - learning_rate: 2.5000e-05
# Epoch 42/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 590ms/step - accuracy: 0.9882 - loss: 0.9073 - val_accuracy: 0.9747 - val_loss: 0.9470 - learning_rate: 2.5000e-05
# Epoch 43/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 562ms/step - accuracy: 0.9961 - loss: 0.8582 - val_accuracy: 0.9755 - val_loss: 0.9128 - learning_rate: 2.5000e-05
# Epoch 44/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 554ms/step - accuracy: 0.9905 - loss: 0.8357 - val_accuracy: 0.9510 - val_loss: 0.9968 - learning_rate: 2.5000e-05
# Epoch 45/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 563ms/step - accuracy: 0.9946 - loss: 0.7946 - val_accuracy: 0.9825 - val_loss: 0.8194 - learning_rate: 2.5000e-05
# Epoch 46/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 563ms/step - accuracy: 0.9967 - loss: 0.7593 - val_accuracy: 0.9851 - val_loss: 0.7899 - learning_rate: 2.5000e-05
# Epoch 47/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 560ms/step - accuracy: 0.9926 - loss: 0.7335 - val_accuracy: 0.9860 - val_loss: 0.7434 - learning_rate: 2.5000e-05
# Epoch 48/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 567ms/step - accuracy: 0.9939 - loss: 0.7047 - val_accuracy: 0.9677 - val_loss: 0.7980 - learning_rate: 2.5000e-05
# Epoch 49/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 563ms/step - accuracy: 0.9905 - loss: 0.6846 - val_accuracy: 0.9886 - val_loss: 0.6953 - learning_rate: 2.5000e-05
# Epoch 50/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 559ms/step - accuracy: 0.9966 - loss: 0.6377 - val_accuracy: 0.9825 - val_loss: 0.6818 - learning_rate: 2.5000e-05
# Epoch 51/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 568ms/step - accuracy: 0.9970 - loss: 0.6108 - val_accuracy: 0.9799 - val_loss: 0.6705 - learning_rate: 2.5000e-05
# Epoch 52/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 570ms/step - accuracy: 0.9966 - loss: 0.5876 - val_accuracy: 0.9650 - val_loss: 0.7117 - learning_rate: 2.5000e-05
# Epoch 53/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 560ms/step - accuracy: 0.9958 - loss: 0.5635 - val_accuracy: 0.9685 - val_loss: 0.6740 - learning_rate: 2.5000e-05
# Epoch 54/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 567ms/step - accuracy: 0.9981 - loss: 0.5328 - val_accuracy: 0.9851 - val_loss: 0.5767 - learning_rate: 2.5000e-05
# Epoch 55/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 568ms/step - accuracy: 0.9952 - loss: 0.5142 - val_accuracy: 0.9720 - val_loss: 0.5972 - learning_rate: 2.5000e-05
# Epoch 56/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 85s 569ms/step - accuracy: 0.9930 - loss: 0.5057 - val_accuracy: 0.9624 - val_loss: 0.6284 - learning_rate: 2.5000e-05
# Epoch 57/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 563ms/step - accuracy: 0.9967 - loss: 0.4666 - val_accuracy: 0.9720 - val_loss: 0.5419 - learning_rate: 2.5000e-05
# Epoch 58/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 561ms/step - accuracy: 0.9955 - loss: 0.4475 - val_accuracy: 0.9738 - val_loss: 0.5198 - learning_rate: 2.5000e-05
# Epoch 59/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 563ms/step - accuracy: 0.9940 - loss: 0.4347 - val_accuracy: 0.9580 - val_loss: 0.5410 - learning_rate: 2.5000e-05
# Epoch 60/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 560ms/step - accuracy: 0.9927 - loss: 0.4163 - val_accuracy: 0.9790 - val_loss: 0.4716 - learning_rate: 2.5000e-05
# Epoch 61/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 141s 563ms/step - accuracy: 0.9961 - loss: 0.3937 - val_accuracy: 0.9773 - val_loss: 0.4725 - learning_rate: 2.5000e-05
# Epoch 62/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 564ms/step - accuracy: 0.9956 - loss: 0.3798 - val_accuracy: 0.9659 - val_loss: 0.4692 - learning_rate: 2.5000e-05
# Epoch 63/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 563ms/step - accuracy: 0.9912 - loss: 0.3686 - val_accuracy: 0.9738 - val_loss: 0.4766 - learning_rate: 2.5000e-05
# Epoch 64/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 566ms/step - accuracy: 0.9928 - loss: 0.3512 - val_accuracy: 0.9790 - val_loss: 0.4076 - learning_rate: 2.5000e-05
# Epoch 65/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 564ms/step - accuracy: 0.9949 - loss: 0.3359 - val_accuracy: 0.9755 - val_loss: 0.4146 - learning_rate: 2.5000e-05
# Epoch 66/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 596ms/step - accuracy: 0.9966 - loss: 0.3205 - val_accuracy: 0.9764 - val_loss: 0.3987 - learning_rate: 2.5000e-05
# Epoch 67/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 89s 601ms/step - accuracy: 0.9959 - loss: 0.3104 - val_accuracy: 0.9668 - val_loss: 0.4094 - learning_rate: 2.5000e-05
# Epoch 68/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 83s 563ms/step - accuracy: 0.9944 - loss: 0.3007 - val_accuracy: 0.9773 - val_loss: 0.3645 - learning_rate: 2.5000e-05
# Epoch 69/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 84s 564ms/step - accuracy: 0.9945 - loss: 0.2933 - val_accuracy: 0.9808 - val_loss: 0.3560 - learning_rate: 2.5000e-05
# Epoch 70/70
# 144/144 ━━━━━━━━━━━━━━━━━━━━ 142s 556ms/step - accuracy: 0.9921 - loss: 0.2853 - val_accuracy: 0.9781 - val_loss: 0.3691 - learning_rate: 2.5000e-05

# %%
# 4. Evaluate the Model
test_loss, test_acc = model.evaluate(test_generator, steps=test_generator.samples // batch_size)
print(f"Test Accuracy: {test_acc:.2f}")
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 0.9779 - loss: 0.3397
# Test Accuracy: 0.98

# %%
import matplotlib.pyplot as plt

# Extract the training history
history = History.history

# Plot training & validation accuracy
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history['accuracy'], label='Train Accuracy')
plt.plot(history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Plot training & validation loss
plt.subplot(1, 2, 2)
plt.plot(history['loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
final_train_acc = History.history['accuracy'][-1]
final_val_acc = History.history['val_accuracy'][-1]
final_train_loss = History.history['loss'][-1]
final_val_loss = History.history['val_loss'][-1]

print(f"Final Training Accuracy: {final_train_acc:.4f}")
print(f"Final Validation Accuracy: {final_val_acc:.4f}")
print(f"Final Training Loss: {final_train_loss:.4f}")
print(f"Final Validation Loss: {final_val_loss:.4f}")
# Out:
# Final Training Accuracy: 0.9948
# Final Validation Accuracy: 0.9781
# Final Training Loss: 0.2762
# Final Validation Loss: 0.3691

# %%
from sklearn.metrics import roc_curve, roc_auc_score
from sklearn.preprocessing import label_binarize


# 2. Get Predicted Probabilities for Test Data
y_pred_prob = model.predict(test_generator, steps=len(test_generator)) # Use len(test_generator) to predict on all batches

# ... (rest of the code remains the same)

# 3. Get True Labels
y_true = test_generator.classes  # True labels from test generator

# 4. Binarize True Labels (for multi-class classification)
num_classes = len(test_generator.class_indices)  # Number of classes
y_true_binarized = label_binarize(y_true, classes=range(num_classes))

# 5. Plot ROC Curve
plt.figure(figsize=(10, 8))

# Loop through each class and compute ROC
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(y_true_binarized[:, i], y_pred_prob[:, i])
    auc = roc_auc_score(y_true_binarized[:, i], y_pred_prob[:, i])
    plt.plot(fpr, tpr, label=f'Class {i} (AUC = {auc:.2f})')

# Add diagonal line (random guess reference)
plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')

# Finalize the plot
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.grid()
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

# 5. Confusion Matrix
y_true = test_generator.classes
y_pred = np.argmax(model.predict(test_generator), axis=1)

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=test_generator.class_indices.keys(), yticklabels=test_generator.class_indices.keys())
plt.title("Confusion Matrix")
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.show()
# Out:
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step

# %%
# Classification Report
report = classification_report(y_true, y_pred, target_names=test_generator.class_indices.keys())
print(report)
# Out:
#               precision    recall  f1-score   support
#
#       glioma       0.98      0.98      0.98       325
#   meningioma       0.98      0.96      0.97       355
#      notumor       0.99      0.99      0.99       400
#    pituitary       0.98      0.99      0.99       352
#
#     accuracy                           0.98      1432
#    macro avg       0.98      0.98      0.98      1432
# weighted avg       0.98      0.98      0.98      1432

# %%
train_files = train_generator.filenames
test_files = test_generator.filenames

# Check for common filenames
overlap = set(train_files).intersection(set(test_files))
print(f"Number of overlapping files: {len(overlap)}")
if overlap:
    print("Data leakage detected!")
else:
    print("No data leakage.")
# Out:
# Number of overlapping files: 0
# No data leakage.
